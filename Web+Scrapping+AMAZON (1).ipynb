# %%
link='https://www.amazon.in/Casio-G-Shock-Digital-Watch-GD-100-1BDR-G310/dp/B0049HSJ76/ref=sr_1_1?crid=2TF9QC2IWV8QP&keywords=g-shock+casio+watches+for+men&qid=1667737000&qu=eyJxc2MiOiI2Ljk2IiwicXNhIjoiNi45OSIsInFzcCI6IjQuNDYifQ%3D%3D&sprefix=g+s%2Caps%2C767&sr=8-1'

# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
page=requests.get(link)

# %%
page.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n\n<!-- sp:end-feature:csm:head-open-part2 -->\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41C-I1lXVwL.css,31ufSReDtSL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css
# ...

# %%
soup=bs(page.content,'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <!-- sp:end-feature:csm:head-open-part2 -->
#   <!-- sp:feature:aui-assets -->
# ...

# %%
from bs4 import BeautifulSoup as bs
import requests
link='https://www.amazon.in/Casio-G-Shock-Digital-Watch-GD-100-1BDR-G310/dp/B0049HSJ76/ref=sr_1_1?crid=2TF9QC2IWV8QP&keywords=g-shock+casio+watches+for+men&qid=1667737000&qu=eyJxc2MiOiI2Ljk2IiwicXNhIjoiNi45OSIsInFzcCI6IjQuNDYifQ%3D%3D&sprefix=g+s%2Caps%2C767&sr=8-1'
page=requests.get(link)
page.content
soup=bs(page.content,'html.parser')
soup1=soup.prettify()
title=soup.title
print(title.string)
# Out:
# Buy Casio G-Shock Digital Black Dial Men's Watch-GD-100-1BDR (G310) at Amazon.in

# %% [markdown]
# # title of product

# %%
title=soup.title
title
# Out:
# <title>Buy Casio G-Shock Digital Black Dial Men's Watch-GD-100-1BDR (G310) at Amazon.in</title>

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(title.string)
# Out:
# Buy Casio G-Shock Digital Black Dial Men's Watch-GD-100-1BDR (G310) at Amazon.in

# %%
price=soup.find('span',class_='a-price aok-align-center').get_text()

print(price)
# Out:
# ₹6,475.00₹6,475.00

# %%
product_price=[]
for i in range (0,len(price)):
    product_price.append(price[i])

print(product_price)
# Out:
# ['₹', '6', ',', '4', '7', '5', '.', '0', '0', '₹', '6', ',', '4', '7', '5', '.', '0', '0']

# %%
para=soup.find_all('th',class_='a-span5 a-size-base')
para
# Out:
# [<th class="a-span5 a-size-base"> Band Colour </th>,
#  <th class="a-span5 a-size-base"> Band Material </th>,
#  <th class="a-span5 a-size-base"> Band Width </th>,
#  <th class="a-span5 a-size-base"> Brand </th>,
#  <th class="a-span5 a-size-base"> Calendar Type </th>,
#  <th class="a-span5 a-size-base"> Case Diameter </th>,
#  <th class="a-span5 a-size-base"> Case Material </th>,
#  <th class="a-span5 a-size-base"> Case Thickness </th>,
#  <th class="a-span5 a-size-base"> Clasp </th>,
#  <th class="a-span5 a-size-base"> Collection </th>,
#  <th class="a-span5 a-size-base"> Dial Colour </th>,
#  <th class="a-span5 a-size-base"> Crystal Material </th>,
#  <th class="a-span5 a-size-base"> Display Type </th>,
#  <th class="a-span5 a-size-base"> Case Shape </th>,
#  <th class="a-span5 a-size-base"> Item Weight </th>,
#  <th class="a-span5 a-size-base"> Model Number </th>,
#  <th class="a-span5 a-size-base"> Part Number </th>,
#  <th class="a-span5 a-size-base"> Special Features </th>,
# ...

# %%
parameter=[]
for i in range(0,len(para)):
    parameter.append(para[i].get_text())
print(parameter)
# Out:
# [' Band Colour ', ' Band Material ', ' Band Width ', ' Brand ', ' Calendar Type ', ' Case Diameter ', ' Case Material ', ' Case Thickness ', ' Clasp ', ' Collection ', ' Dial Colour ', ' Crystal Material ', ' Display Type ', ' Case Shape ', ' Item Weight ', ' Model Number ', ' Part Number ', ' Special Features ', ' Warranty Type ', ' Movement ', ' Water Resistance Depth ', ' Warranty Description ', ' Warranty ']

# %%
spec=soup.find_all('td',class_='a-span7 a-size-base')
spec
# Out:
# [<td class="a-span7 a-size-base"> Black </td>,
#  <td class="a-span7 a-size-base"> Resin </td>,
#  <td class="a-span7 a-size-base"> 2 Inches </td>,
#  <td class="a-span7 a-size-base"> Casio </td>,
#  <td class="a-span7 a-size-base"> Day-Date-Month </td>,
#  <td class="a-span7 a-size-base"> 5.5 Centimeters </td>,
#  <td class="a-span7 a-size-base"> Resin </td>,
#  <td class="a-span7 a-size-base"> 17 </td>,
#  <td class="a-span7 a-size-base"> Buckle </td>,
#  <td class="a-span7 a-size-base"> G-Shock </td>,
#  <td class="a-span7 a-size-base"> Black </td>,
#  <td class="a-span7 a-size-base"> Mineral </td>,
#  <td class="a-span7 a-size-base"> Digital </td>,
#  <td class="a-span7 a-size-base"> Round </td>,
#  <td class="a-span7 a-size-base"> 73 Grams </td>,
#  <td class="a-span7 a-size-base"> GD-100-1BDR (G310) </td>,
#  <td class="a-span7 a-size-base"> GD-100-1BDR (G310) </td>,
#  <td class="a-span7 a-size-base"> Shock resistant, Luminous, Light, Timer, Stopwatch </td>,
# ...

# %%
specifications=[]
for i in range(0,len(spec)):
    specifications.append(spec[i].get_text())
specifications
# Out:
# [' Black ',
#  ' Resin ',
#  ' 2 Inches ',
#  ' Casio ',
#  ' Day-Date-Month ',
#  ' 5.5 Centimeters ',
#  ' Resin ',
#  ' 17 ',
#  ' Buckle ',
#  ' G-Shock ',
#  ' Black ',
#  ' Mineral ',
#  ' Digital ',
#  ' Round ',
#  ' 73 Grams ',
#  ' GD-100-1BDR (G310) ',
#  ' GD-100-1BDR (G310) ',
#  ' Shock resistant, Luminous, Light, Timer, Stopwatch ',
#  ' Manufacturer ',
#  ' Quartz ',
#  ' 100 Meters ',
#  '  2 Years Manufacturer warranty from the date of purchase How to avail Warranty? • Register your product on https://register.casio.in/ • 6 months additional warranty for products registered online • To claim your warranty, produce original bill copy/invoice at authorized Casio service center (Warranty card & stamp is not mandatory for online purchases) • For any service related enquiries and feedback, call Casio India Helpline Number: - 011-66999200 or Email at casiocare@casio.co.in ',
# ...

# %%
cust_name=soup.find_all('span',class_='a-profile-name')
cust_name
# Out:
# [<span class="a-profile-name">Amazon Customer</span>,
#  <span class="a-profile-name">akhilkumar</span>,
#  <span class="a-profile-name">Avishek</span>,
#  <span class="a-profile-name">Rasika Otari</span>,
#  <span class="a-profile-name">Suhas Patkar</span>,
#  <span class="a-profile-name">Pratik Pandit</span>,
#  <span class="a-profile-name">Nived Kannada</span>,
#  <span class="a-profile-name">Rushi</span>,
#  <span class="a-profile-name">Dadu</span>,
#  <span class="a-profile-name">Aleksey</span>,
#  <span class="a-profile-name">Scott</span>,
#  <span class="a-profile-name">Auren </span>,
#  <span class="a-profile-name">Swaysquatch </span>,
#  <span class="a-profile-name">Eduardo Montoya</span>]

# %%
name=[]
for i in range (0,len(cust_name)):
    name.append(cust_name[i].get_text())
name
# Out:
# ['Amazon Customer',
#  'akhilkumar',
#  'Avishek',
#  'Rasika Otari',
#  'Suhas Patkar',
#  'Pratik Pandit',
#  'Nived Kannada',
#  'Rushi',
#  'Dadu',
#  'Aleksey',
#  'Scott',
#  'Auren ',
#  'Swaysquatch ',
#  'Eduardo Montoya']

# %%
review=soup.find_all('span',class_='review-title')
review
# Out:
# [<span class="a-size-base review-title a-color-base review-title-content a-text-bold" data-hook="review-title">
#  <span>Solid and Reliable</span>
#  </span>,
#  <span class="a-size-base review-title a-color-base review-title-content a-text-bold" data-hook="review-title">
#  <span>Five years, lots of miles...still my favorite watch....</span>
#  </span>,
#  <span class="a-size-base review-title a-color-base review-title-content a-text-bold" data-hook="review-title">
#  <span>Fantastic watch</span>
#  </span>,
#  <span class="a-size-base review-title a-color-base review-title-content a-text-bold" data-hook="review-title">
#  <span>Fast Delivery</span>
#  </span>,
#  <span class="a-size-base review-title a-color-base review-title-content a-text-bold" data-hook="review-title">
#  <span class="cr-original-review-content">BUEN PRODUCTO, BUEN VENDEDOR</span><span class="cr-translated-review-content aok-hidden"></span>
#  </span>]

# %%
review1=soup.find_all('a',class_='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold')
review1
# Out:
# [<a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R35ULS00UJQBGR?ASIN=B0049HSJ76">
#  <span>Super watch</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R35NUDM8DTQL6H?ASIN=B0049HSJ76">
#  <span>Classic g shock</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R5RUSH5PWCCDB?ASIN=B0049HSJ76">
#  <span>Super cool</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R17GHVQ89LXWSS?ASIN=B0049HSJ76">
#  <span>Great Product.</span>
#  </a>,
# ...

# %%
feedback=[]
for i in range (0,len(review1)):
    feedback.append(review1[i].get_text())
feedback
# Out:
# ['\nSuper watch\n',
#  '\nClassic g shock\n',
#  '\nSuper cool\n',
#  '\nGreat Product.\n',
#  '\nOriginally\n',
#  '\nGreat watch but Amazon packed it the worst way\n',
#  '\nBest black digital watch\n',
#  '\nits a cool watch\n']

# %%
for i in range (0,len(review)):
    feedback.append(review[i].get_text())
feedback
# Out:
# ['\nSuper watch\n',
#  '\nClassic g shock\n',
#  '\nSuper cool\n',
#  '\nGreat Product.\n',
#  '\nOriginally\n',
#  '\nGreat watch but Amazon packed it the worst way\n',
#  '\nBest black digital watch\n',
#  '\nits a cool watch\n',
#  '\nSolid and Reliable\n',
#  '\nFive years, lots of miles...still my favorite watch....\n',
#  '\nFantastic watch\n',
#  '\nFast Delivery\n',
#  '\nBUEN PRODUCTO, BUEN VENDEDOR\n']

# %%
discard.feedback()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-2a77c00f8d69> in <module>()
# ----> 1 discard.feedback()
#
# NameError: name 'discard' is not defined

# %%
import pandas as pd

# %%
tb=pd.DataFrame()
tb['Parameter']=parameter
tb['Specifications']=specifications

# %%
tb
# Out:
#                    Parameter  \
# 0               Band Colour
# 1             Band Material
# 2                Band Width
# 3                     Brand
# 4             Calendar Type
# 5             Case Diameter
# 6             Case Material
# 7            Case Thickness
# 8                     Clasp
# 9                Collection
# 10              Dial Colour
# 11         Crystal Material
# 12             Display Type
# 13               Case Shape
# 14              Item Weight
# 15             Model Number
# 16              Part Number
# 17         Special Features
# 18            Warranty Type
# 19                 Movement
# 20   Water Resistance Depth
# 21     Warranty Description
# 22                 Warranty
#
#                                        Specifications
# 0                                              Black
# 1                                              Resin
# 2                                           2 Inches
# ...

# %%
fb=pd.DataFrame()
fb['Customer Name']=name
fb['Customer Review']=review
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-d533d7c4e193> in <module>()
#       1 fb=pd.DataFrame()
#       2 fb['Customer Name']=name
# ----> 3 fb['Customer Review']=review
#
# ~\anaconda3\anaconda1\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# ~\anaconda3\anaconda1\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# ~\anaconda3\anaconda1\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    2566
# ...
